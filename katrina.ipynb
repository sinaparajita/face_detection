# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
from ultralytics.data.utils import autosplit

# %%
autosplit('images',[0.8,0.2,0.0])
# Out:
# Autosplitting images from images
# 100%|██████████| 213/213 [00:00<00:00, 4458.95it/s]

# %%
# !touch train.yaml

# %%
model=YOLO('yolov10m.pt')
# Out:
# ...
# 100%|██████████| 32.1M/32.1M [00:00<00:00, 37.4MB/s]

# %%
res=model('images/01163363-WhatsApp_Image_2024-08-01_at_12.55.49_PM_13.jpeg')
# Out:
# image 1/1 /content/images/01163363-WhatsApp_Image_2024-08-01_at_12.55.49_PM_13.jpeg: 384x640 3 persons, 1173.4ms
# Speed: 17.6ms preprocess, 1173.4ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)

# %%
import matplotlib.pyplot as plt
img=res[0].plot()
plt.imshow(img)

# %%
model.train(data='/content/train.yaml',epochs=200,batch=10)
# Out:
# Ultralytics YOLOv8.2.77 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
new_model=YOLO('/content/runs/detect/train/weights/best.pt')

# %%
import matplotlib.pyplot as plt
res=new_model('kat.jpg')
plt.imshow(res[0].plot())
# Out:
# image 1/1 /content/kat.jpg: 480x640 2 katrinas, 27.6ms
# Speed: 2.5ms preprocess, 27.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)

# %%
# !unzip katrina.zip
# Out:
# Archive:  katrina.zip
#    creating: images/
#    creating: labels/
#   inflating: classes.txt
#   inflating: notes.json
#   inflating: images/01163363-WhatsApp_Image_2024-08-01_at_12.55.49_PM_13.jpeg
#   inflating: images/02926c89-AnyConv.com__k60.jpg
#   inflating: images/04167478-WhatsApp_Image_2024-08-01_at_12.58.24_PM.jpeg
#   inflating: images/04ffa344-WhatsApp_Image_2024-08-01_at_12.55.49_PM_11.jpeg
#   inflating: images/062754e6-WhatsApp_Image_2024-08-01_at_12.55.49_PM_36.jpeg
#   inflating: images/06c4c736-AnyConv.com__13.jpg
#   inflating: images/0931b996-AnyConv.com__k56.jpg
#   inflating: images/0aec5949-WhatsApp_Image_2024-08-01_at_12.55.49_PM_66.jpeg
#   inflating: images/0bd4771a-WhatsApp_Image_2024-08-01_at_12.55.49_PM_35.jpeg
#   inflating: images/0c28969a-AnyConv.com__k54.jpg
#   inflating: images/0e1252fd-WhatsApp_Image_2024-08-01_at_12.55.49_PM_6.jpeg
#   inflating: images/11424719-AnyConv.com__k13.jpg
# ...
